# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pycocotools.coco import COCO

# %%
with open('instances_train.json') as json_file:
    train_data = json.load(json_file)

# %%
# !git clone https://github.com/surfriderfoundationeurope/surfnet.git

# %%
# !pip install -r ./surfnet/requirements.txt

# %%
import json 


coco = COCO(annotation_file = 'instances_train.json')

coco_categories = coco.dataset['categories'][1:]

nb_anns_per_cat = {cat['name']: len(coco.getAnnIds(catIds=[cat['id']])) for cat in coco_categories}
nb_anns_per_cat = {k:v for k,v in sorted(nb_anns_per_cat.items(), key=lambda x: x[1], reverse=True)}
cat_names = list(nb_anns_per_cat.keys())
nb_images = list(nb_anns_per_cat.values())

plt.bar(x = cat_names, height = nb_images)
plt.xticks(range(len(cat_names)), cat_names, rotation='vertical')
plt.ylabel('Number of annotations')
plt.tight_layout()
plt.autoscale(True)
plt.savefig('dataset_analysis')
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!

# %%
coco.dataset['annotations']

# %%
nb_anns_per_cat
# Out:
# {'Sheet / tarp / plastic bag / fragment': 3086,
#  'Bottle-shaped': 987,
#  'Unclear': 975,
#  'Easily namable': 494,
#  'Other packaging': 430,
#  'Fishing net / cord': 149,
#  'Can-shaped': 138,
#  'Insulating material': 89,
#  'Drum': 50,
#  'Tire': 43}
